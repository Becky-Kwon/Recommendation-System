# %% [raw]
# 리뷰에 place id 넣기

# %%
pwd
# Out:
# 'C:\\Users\\runia\\Desktop\\py'

# %%
import pandas as pd

# %%
total = pd.read_csv('tripadvisor-total.csv')
total
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-8-5875d7c56285> in <module>
# ----> 1 total = pd.read_csv('tripadvisor-total.csv')
#       2 total
#
# ~\Anaconda3\envs\py36\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     686     )
#     687
# ...

# %%
place = pd.read_excel('places.xlsx')
place
# Out:
#         id   category          place  \
# 0        1      서울 쇼핑       교보문고 광화문
# 1        2      서울 쇼핑       롯데월드타워&몰
# 2        3      서울 쇼핑    SM타운 코엑스아티움
# 3        4      서울 쇼핑  홍대앞 예술시장 프리마켓
# 4        5      서울 쇼핑           광장시장
# ...    ...        ...            ...
# 2217  2301  서울 소재 이벤트         서울불꽃축제
# 2218  2302  서울 소재 이벤트       하이서울페스티벌
# 2219  2303  서울 소재 이벤트        한성백제문화제
# 2220  2304  서울 소재 이벤트       서울 김장문화제
# 2221  2305  서울 소재 이벤트        서울의 이벤트
#
#                                                     url
# 0     https://www.tripadvisor.co.kr/Attraction_Revie...
# 1     https://www.tripadvisor.co.kr/Attraction_Revie...
# 2     https://www.tripadvisor.co.kr/Attraction_Revie...
# 3     https://www.tripadvisor.co.kr/Attraction_Revie...
# 4     https://www.tripadvisor.co.kr/Attraction_Revie...
# ...                                                 ...
# 2217  https://www.tripadvisor.co.kr/Attraction_Revie...
# 2218  https://www.tripadvisor.co.kr/Attraction_Revie...
# ...

# %%
review = pd.read_excel('tripadvisor.xlsx')
review
# Out:
#        Unnamed: 0            user_id  rating  \
# 0               0         Alpertbyun       5
# 1               1         Alpertbyun       5
# 2               2        FromCharlie       5
# 3               3            heefeel       4
# 4               4      Voyager809710       4
# ...           ...                ...     ...
# 56467       56467      LindaMN4247OB       4
# 56468       56468  passion4travel296       1
# 56469       56469           mooinoit       4
# 56470       56470           383phamn       4
# 56471       56471        thithil2015       5
#
#                                                   review     date  place_id
# 0      교보문고\n광화문역 5호선지하철역이랑 연결되어 있어서 찾아가기 아주좋아요 광화문교보...   2020/5         1
# 1      교보문고\n광화문역이랑 바로 연결되어있는 교보문고. 책 종류도 많이있고 책보기에도 ...  2019/12         1
# 2      호텔이랑 프로모션도 하네요\n교보문고 애정하는 1인으로써, 이런 건 자주 하시면 좋...   2019/4         1
# 3      평일에 책 보기 좋은 곳\n평일에 근처 약속이 있어 방문했습니다. 주말에 갔을때는 ...   2019/3         1
# ...

# %%
review['place'] = 'NA'
review
# Out:
#        Unnamed: 0            user_id  rating  \
# 0               0         Alpertbyun       5
# 1               1         Alpertbyun       5
# 2               2        FromCharlie       5
# 3               3            heefeel       4
# 4               4      Voyager809710       4
# ...           ...                ...     ...
# 56467       56467      LindaMN4247OB       4
# 56468       56468  passion4travel296       1
# 56469       56469           mooinoit       4
# 56470       56470           383phamn       4
# 56471       56471        thithil2015       5
#
#                                                   review     date  place_id  \
# 0      교보문고\n광화문역 5호선지하철역이랑 연결되어 있어서 찾아가기 아주좋아요 광화문교보...   2020/5         1
# 1      교보문고\n광화문역이랑 바로 연결되어있는 교보문고. 책 종류도 많이있고 책보기에도 ...  2019/12         1
# 2      호텔이랑 프로모션도 하네요\n교보문고 애정하는 1인으로써, 이런 건 자주 하시면 좋...   2019/4         1
# 3      평일에 책 보기 좋은 곳\n평일에 근처 약속이 있어 방문했습니다. 주말에 갔을때는 ...   2019/3         1
# ...

# %%
type(int(review['place_id'][0]))
# Out:
# int

# %%
type(int(place_id))
# Out:
# int

# %%
print(place_id, place_name)
# Out:
# 2305 서울의 이벤트

# %%
review['place_id']
# Out:
# 0           1
# 1           1
# 2           1
# 3           1
# 4           1
#          ...
# 56467    2388
# 56468    2389
# 56469    2391
# 56470    2391
# 56471    2391
# Name: place_id, Length: 56472, dtype: int64

# %%
place.iloc[0, 2]
# Out:
# '교보문고 광화문'

# %%
review['place_id'][0]
# Out:
# 1

# %%
review.loc[review["place_id"] == place_id, "place"] = place_name

# %%
review
# Out:
#        Unnamed: 0            user_id  rating  \
# 0               0         Alpertbyun       5
# 1               1         Alpertbyun       5
# 2               2        FromCharlie       5
# 3               3            heefeel       4
# 4               4      Voyager809710       4
# ...           ...                ...     ...
# 56467       56467      LindaMN4247OB       4
# 56468       56468  passion4travel296       1
# 56469       56469           mooinoit       4
# 56470       56470           383phamn       4
# 56471       56471        thithil2015       5
#
#                                                   review     date  place_id  \
# 0      교보문고\n광화문역 5호선지하철역이랑 연결되어 있어서 찾아가기 아주좋아요 광화문교보...   2020/5         1
# 1      교보문고\n광화문역이랑 바로 연결되어있는 교보문고. 책 종류도 많이있고 책보기에도 ...  2019/12         1
# 2      호텔이랑 프로모션도 하네요\n교보문고 애정하는 1인으로써, 이런 건 자주 하시면 좋...   2019/4         1
# 3      평일에 책 보기 좋은 곳\n평일에 근처 약속이 있어 방문했습니다. 주말에 갔을때는 ...   2019/3         1
# ...

# %%
for i in range(len(place)):
    place_id =  place.iloc[i, 0]
    place_name = place.iloc[i, 2]
    print(place_id, place_name)
    
    review.loc[review["place_id"] == place_id, "place"] = place_name
# Out:
# 1 교보문고 광화문
# 2 롯데월드타워&몰
# 3 SM타운 코엑스아티움
# 4 홍대앞 예술시장 프리마켓
# 5 광장시장
# 6 고투 몰
# 7 신세계 백화점 본점
# 8 타임스퀘어
# 9 가로수길
# 10 라인프렌즈 플래그십 스토어 명동역점
# 11 스타필드 코엑스몰
# 12 통인시장
# 13 마장 축산물시장
# 14 남대문시장
# 15 쌈지길
# 16 롯데백화점 본점
# 17 강남 지하상가
# 18 중부시장
# 19 IFC 몰
# 20 동대문 쇼핑몰
# 21 동대문 시장
# 22 노량진 수산물 도매시장
# 23 디큐브시브
# 24 삼성 딜라이트
# 25 카카오프렌즈 홍대 플래그십 스토어
# 26 고속터미널상가
# 27 신라면세점
# 28 Unni Tour
# 29 현대백화점 압구정본점
# 30 커먼그라운드
# 31 압구정 로데오 거리
# 32 신세계 강남점
# 33 프린세스다이어리 이대점
# 34 경동시장
# 35 라인 프렌즈 플래그십 스토어 가로수길점
# 36 롯데아울렛 서울역점
# 37 스타일난다 핑크호텔
# 38 아이파크몰
# 39 동대문 밀리오레
# 40 롯데 영플라자 명동점
# 41 서울약령시장
# 42 두타
# 43 망원시장
# 44 메세나폴리스몰
# 45 광희 패션몰
# 46 에이랜드
# 47 가락시장
# 48 양재동 화훼공판장
# 49 롯데 면세점 본점
# 50 동화 면세점
# 51 마리오 아울렛
# 52 갤러리아 백화점 본점
# 53 창신동 문구 완구 거리
# 54 킴즈 클럽
# 55 생활창작가게 KEY
# 56 아크앤북 - 시청점
# 57 남평화 상가
# 58 명동지하상가
# 59 고관한복촬영소 명동점
# 60 방산 종합시장
# 61 헬로키티아일랜드 in N서울타워
# 62 롯데 피트인
# 63 회현 지하 상가
# 64 에덴악세사리
# 65 KT&G 상상마당
# 66 동묘벼룩시장
# 67 에이피엠 플레이스
# 68 가든파이브
# 69 Savile Row: Custom Tailor
# 70 낙원 악기 상가
# 71 동대문 문구거리
# ...

# %%
review[0:100]
# Out:
#     Unnamed: 0        user_id  rating  \
# 0            0     Alpertbyun       5
# 1            1     Alpertbyun       5
# 2            2    FromCharlie       5
# 3            3        heefeel       4
# 4            4  Voyager809710       4
# ..         ...            ...     ...
# 95          95  Voyager809710       4
# 96          96    winnie_ming       4
# 97          97       ab961004       5
# 98          98       JAEHHYUK       5
# 99          99    sweetchocho       5
#
#                                                review     date  place_id  \
# 0   교보문고\n광화문역 5호선지하철역이랑 연결되어 있어서 찾아가기 아주좋아요 광화문교보...   2020/5         1
# 1   교보문고\n광화문역이랑 바로 연결되어있는 교보문고. 책 종류도 많이있고 책보기에도 ...  2019/12         1
# 2   호텔이랑 프로모션도 하네요\n교보문고 애정하는 1인으로써, 이런 건 자주 하시면 좋...   2019/4         1
# 3   평일에 책 보기 좋은 곳\n평일에 근처 약속이 있어 방문했습니다. 주말에 갔을때는 ...   2019/3         1
# 4   위치가 아주 좋습니다.\n지하철역과 연결되어 약속장소로 아주 좋습니다. 스마트폰이나...   2019/1         1
# ...

# %%
review[review['place_id'] == 2]['place']
# Out:
# 74     롯데월드타워&몰
# 75     롯데월드타워&몰
# 76     롯데월드타워&몰
# 77     롯데월드타워&몰
# 78     롯데월드타워&몰
#          ...
# 272    롯데월드타워&몰
# 273    롯데월드타워&몰
# 274    롯데월드타워&몰
# 275    롯데월드타워&몰
# 276    롯데월드타워&몰
# Name: place, Length: 203, dtype: object
